# %%
import seaborn as sns

# %%
import pandas as pd

# %%
df=pd.read_csv("housing (2).csv")

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
df.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
sns.boxplot(data=df,x='ocean_proximity',y='median_house_value')
# Out:
# <Axes: xlabel='ocean_proximity', ylabel='median_house_value'>

# %%
#sns.pairplot(df)

# %%
df.corr(numeric_only=True)
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# median_house_value  -0.045967 -0.144160            0.105623     0.134153
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069608    0.099773    0.055310      -0.015176
# latitude                 -0.066983   -0.108785   -0.071035      -0.079809
# housing_median_age       -0.320451   -0.296244   -0.302916      -0.119034
# total_rooms               0.930380    0.857126    0.918484       0.198050
# total_bedrooms            1.000000    0.877747    0.979728      -0.007723
# population                0.877747    1.000000    0.907222       0.004834
# households                0.979728    0.907222    1.000000       0.013033
# median_income            -0.007723    0.004834    0.013033       1.000000
# median_house_value        0.049686   -0.024650    0.065843       0.688075
#
#                     median_house_value
# longitude                    -0.045967
# latitude                     -0.144160
# housing_median_age            0.105623
# total_rooms                   0.134153
# total_bedrooms                0.049686
# population                   -0.024650
# households                    0.065843
# median_income                 0.688075
# median_house_value            1.000000

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
sns.histplot(df['total_bedrooms'])
# Out:
# <Axes: xlabel='total_bedrooms', ylabel='Count'>

# %%
res=df['total_bedrooms'].median()

# %%
df['total_bedrooms'].fillna(res,inplace=True)
# Out:
# C:\Users\rb190\AppData\Local\Temp\ipykernel_9652\3409910366.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['total_bedrooms'].fillna(res,inplace=True)

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['ocean_proximity'] = le.fit_transform(df['ocean_proximity'])

# %%
X=df.drop('median_house_value',axis=1)

# %%
y=df['median_house_value']

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X=sc.fit_transform(X)

# %%
y = sc.fit_transform(y.values.reshape(-1, 1))

# %%
X
# Out:
# array([[-1.32783522,  1.05254828,  0.98214266, ..., -0.97703285,
#          2.34476576,  1.2910888 ],
#        [-1.32284391,  1.04318455, -0.60701891, ...,  1.66996103,
#          2.33223796,  1.2910888 ],
#        [-1.33282653,  1.03850269,  1.85618152, ..., -0.84363692,
#          1.7826994 ,  1.2910888 ],
#        ...,
#        [-0.8237132 ,  1.77823747, -0.92485123, ..., -0.17404163,
#         -1.14259331, -0.11673923],
#        [-0.87362627,  1.77823747, -0.84539315, ..., -0.39375258,
#         -1.05458292, -0.11673923],
#        [-0.83369581,  1.75014627, -1.00430931, ...,  0.07967221,
#         -0.78012947, -0.11673923]])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20640 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  int64
# dtypes: float64(9), int64(1)
# memory usage: 1.6 MB

# %%
y
# Out:
# array([[ 2.12963148],
#        [ 1.31415614],
#        [ 1.25869341],
#        ...,
#        [-0.99274649],
#        [-1.05860847],
#        [-1.01787803]])

# %%
from sklearn.model_selection import train_test_split

# %%
#X_train, X_test, y_train, y_test = train_test_split(
 #   X, y, test_size=0.33, random_state=42)

# %%
from sklearn.model_selection import cross_val_score

# %%
X
# Out:
# array([[-1.32783522,  1.05254828,  0.98214266, ..., -0.97703285,
#          2.34476576,  1.2910888 ],
#        [-1.32284391,  1.04318455, -0.60701891, ...,  1.66996103,
#          2.33223796,  1.2910888 ],
#        [-1.33282653,  1.03850269,  1.85618152, ..., -0.84363692,
#          1.7826994 ,  1.2910888 ],
#        ...,
#        [-0.8237132 ,  1.77823747, -0.92485123, ..., -0.17404163,
#         -1.14259331, -0.11673923],
#        [-0.87362627,  1.77823747, -0.84539315, ..., -0.39375258,
#         -1.05458292, -0.11673923],
#        [-0.83369581,  1.75014627, -1.00430931, ...,  0.07967221,
#         -0.78012947, -0.11673923]])

# %%
X_test.shape
# Out:
# (6812, 9)

# %%
X_train.shape
# Out:
# (13828, 9)

# %%
y_test.shape
# Out:
# (6812, 1)

# %%
y_train.shape
# Out:
# (13828, 1)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr=RandomForestRegressor()

# %%
scores=cross_val_score(rfr, X, y, cv=3,scoring='neg_mean_squared_error')
print(scores.mean())
# Out:
# C:\Users\rb190\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rb190\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\rb190\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# -0.4997608719545051

# %%
rfr.fit(X_train,y_train)
# Out:
# C:\Users\rb190\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
y_pred=rfr.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8081043120172424

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knr= KNeighborsRegressor()

# %%
scores=cross_val_score(knr, X, y, cv=3,scoring='neg_mean_squared_error')
print(scores.mean())
# Out:
# -0.4356182010387594

# %%
knr.fit(X_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred=knr.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.709618891724723

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr=DecisionTreeRegressor()

# %%
scores=cross_val_score(dtr, X, y, cv=3,scoring='neg_mean_squared_error')
print(scores.mean())
# Out:
# -0.952838234157258

# %%
dtr.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=dtr.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.6500661247380635

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
scores=cross_val_score(lr, X, y, cv=3,scoring='neg_mean_squared_error')
print(scores.mean())
# Out:
# -0.40010772224160157

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.6308586222589585

# %%
import keras

# %%
model=keras.Sequential()

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.add(
    keras.Input(shape=(9,))
)

# %%
model.add(keras.layers.Dense(
    32,
    activation='relu',
))

# %%
model.add(keras.layers.Dense(
    64,
    activation='relu',
))

# %%
model.add(keras.layers.Dense(
    1,
    activation='linear',
))

# %%
model.compile(
    optimizer="adam",
    loss='mse',
    metrics=['mae'],
)

# %%
model.fit(
    x=X_train,
    y=y_train,
    batch_size=32,
    epochs=10,
    verbose="auto",
    validation_data=(X_test,y_test)
)
# Out:
# Epoch 1/10
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.5238 - mae: 0.5379 - val_loss: 0.3217 - val_mae: 0.4048
# Epoch 2/10
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3033 - mae: 0.3900 - val_loss: 0.2922 - val_mae: 0.3804
# Epoch 3/10
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2903 - mae: 0.3759 - val_loss: 0.2789 - val_mae: 0.3686
# Epoch 4/10
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2777 - mae: 0.3675 - val_loss: 0.2780 - val_mae: 0.3759
# Epoch 5/10
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2661 - mae: 0.3593 - val_loss: 0.2663 - val_mae: 0.3564
# Epoch 6/10
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2380 - mae: 0.3413 - val_loss: 0.2691 - val_mae: 0.3586
# Epoch 7/10
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.2536 - mae: 0.3522 - val_loss: 0.2747 - val_mae: 0.3607
# Epoch 8/10
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2377 - mae: 0.3392 - val_loss: 0.2551 - val_mae: 0.3492
# Epoch 9/10
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2359 - mae: 0.3359 - val_loss: 0.2519 - val_mae: 0.3436
# Epoch 10/10
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2471 - mae: 0.3412 - val_loss: 0.2509 - val_mae: 0.3474

# %%
model.evaluate(X_test,y_test)
# Out:
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2735 - mae: 0.3626
# [0.2508603036403656, 0.34743955731391907]
